# %%
import yfinance as yf

symbol = '^GSPC'  # S&P 500 symbol

# Fetch historical data
data = yf.download(symbol, start='2002-01-01', end='2022-12-31')

# Process the data as per your requirements
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2002-01-02  1148.079956  1154.670044  1136.229980  1154.670044  1154.670044
# 2002-01-03  1154.670044  1165.270020  1154.010010  1165.270020  1165.270020
# 2002-01-04  1165.270020  1176.550049  1163.420044  1172.510010  1172.510010
# 2002-01-07  1172.510010  1176.969971  1163.550049  1164.890015  1164.890015
# 2002-01-08  1164.890015  1167.599976  1157.459961  1160.709961  1160.709961
# ...                 ...          ...          ...          ...          ...
# 2022-12-23  3815.110107  3845.800049  3797.010010  3844.820068  3844.820068
# 2022-12-27  3843.340088  3846.649902  3813.219971  3829.250000  3829.250000
# 2022-12-28  3829.560059  3848.320068  3780.780029  3783.219971  3783.219971
# 2022-12-29  3805.449951  3858.189941  3805.449951  3849.280029  3849.280029
# 2022-12-30  3829.060059  3839.850098  3800.340088  3839.500000  3839.500000
#
#                 Volume
# Date
# ...

# %%
import yfinance as yf
import pandas as pd

# Get the list of S&P 500 tickers
sp500_tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
)[0]['Symbol'].tolist()

# Fetch historical data for each ticker
data = {}
for ticker in sp500_tickers:
    try:
        df = yf.download(ticker, start='2022-01-01', end='2022-12-31')
        if not df.empty:
            data[ticker] = df
    except Exception as e:
        print(f"Failed to download data for {ticker}: {str(e)}")

# Concatenate the data into a single DataFrame
combined_data = pd.concat(data.values(), keys=data.keys(), axis=1)

# Save data to CSV
combined_data.to_csv('sp500_data_with_tickers.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
combined_data
# Out:
#                    MMM                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 2022-01-03  178.320007  179.089996  175.839996  177.740005  165.762421
# 2022-01-04  178.479996  181.259995  178.029999  180.229996  168.084595
# 2022-01-05  177.130005  181.779999  177.000000  179.490005  167.394501
# 2022-01-06  180.880005  181.279999  177.539993  178.000000  166.004898
# 2022-01-07  178.130005  180.490005  177.220001  179.949997  167.823486
# ...                ...         ...         ...         ...         ...
# 2022-12-23  120.790001  121.000000  117.800003  120.139999  116.794731
# 2022-12-27  120.139999  120.830002  119.160004  120.220001  116.872505
# 2022-12-28  120.349998  121.000000  118.250000  118.290001  114.996246
# 2022-12-29  118.870003  120.860001  118.500000  120.570000  117.212761
# 2022-12-30  119.650002  120.029999  118.510002  119.919998  116.580856
#
# ...

# %%
data = []
for ticker in sp500_tickers:
  
    df['Ticker'] = ticker  # Add a new column with the ticker name
    data.append(df)
    

# Concatenate the data into a single DataFrame
combined_data = pd.concat(data)

# Save data to CSV
combined_data.to_csv('sp500_data_with_tickers.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 data = []
# ----> 2 for ticker in sp500_tickers:
#       4     df['Ticker'] = ticker  # Add a new column with the ticker name
#       5     data.append(df)
#
# NameError: name 'sp500_tickers' is not defined

# %%
import pandas as pd
import yfinance as yf

# Get the list of S&P 500 tickers
sp500_tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
)[0]['Symbol'].tolist()

# Fetch historical data for each ticker
data = []
for ticker in sp500_tickers:
    try:
        df = yf.download(ticker, start='2022-12-01', end='2022-12-31')
        if not df.empty:
            df['Ticker'] = ticker  # Add a new column with the ticker name
            data.append(df)
    except Exception as e:
        print(f"Failed to download data for {ticker}: {str(e)}")

# Concatenate the data into a single DataFrame
combined_data = pd.concat(data)

# Save data to CSV
combined_data.to_csv('sp500_data_with_tickers.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
combined_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-01  127.300003  128.869995  125.309998  125.989998  122.481842
# 2022-12-02  124.760002  127.250000  124.239998  126.989998  123.453995
# 2022-12-05  125.070000  125.459999  124.269997  124.629997  121.159706
# 2022-12-06  125.150002  125.730003  123.309998  124.580002  121.111107
# 2022-12-07  124.330002  127.309998  124.099998  126.349998  122.831810
# ...                ...         ...         ...         ...         ...
# 2022-12-23  144.509995  145.889999  143.539993  145.759995  145.106659
# 2022-12-27  145.910004  146.149994  143.570007  145.300003  144.648743
# 2022-12-28  145.179993  146.639999  143.770004  143.830002  143.185333
# 2022-12-29  145.199997  148.509995  145.139999  148.149994  147.485947
# 2022-12-30  147.199997  147.789993  144.740005  146.550003  145.893127
#
#              Volume Ticker
# Date
# 2022-12-01  2638800    MMM
# 2022-12-02  1821900    MMM
# ...

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10511 entries, 2022-12-01 to 2022-12-30
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       10511 non-null  float64
#  1   High       10511 non-null  float64
#  2   Low        10511 non-null  float64
#  3   Close      10511 non-null  float64
#  4   Adj Close  10511 non-null  float64
#  5   Volume     10511 non-null  int64
#  6   Ticker     10511 non-null  object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 656.9+ KB

# %%
combined_data['Ticker'].unique()
# Out:
# array(['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ATVI', 'ADM', 'ADBE', 'ADP',
#        'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 'ARE',
#        'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN',
#        'AMCR', 'AMD', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK',
#        'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA',
#        'AAPL', 'AMAT', 'APTV', 'ACGL', 'ANET', 'AJG', 'AIZ', 'T', 'ATO',
#        'ADSK', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BBWI',
#        'BAX', 'BDX', 'WRB', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK',
#        'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO',
#        'BG', 'CHRW', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX',
#        'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC',
#        'CNP', 'CDAY', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB',
#        'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME',
# ...

# %%
import pandas as pd
import yfinance as yf

# Get the list of S&P 100 tickers
sp100_tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/S%26P_100'
)[2]['Symbol'].tolist()

# Fetch historical data for each ticker
data = []
for ticker in sp100_tickers:
    try:
        df = yf.download(ticker, start='2012-12-01', end='2022-12-31')
        if not df.empty:
            df['Ticker'] = ticker  # Add a new column with the ticker name
            data.append(df)
    except Exception as e:
        print(f"Failed to download data for {ticker}: {str(e)}")

# Concatenate the data into a single DataFrame
combined_data = pd.concat(data)

# Save data to CSV
combined_data.to_csv('sp100_data_with_tickers.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
combined_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-12-03   21.201786   21.235357   20.910713   20.935356   17.951883
# 2012-12-04   20.778570   20.778570   20.433214   20.566071   17.635214
# 2012-12-05   20.318214   20.330357   19.241785   19.242500   16.500261
# 2012-12-06   18.890715   19.761070   18.522499   19.544287   16.759045
# 2012-12-07   19.764286   19.828571   18.928572   19.044643   16.330601
# ...                ...         ...         ...         ...         ...
# 2022-12-23  106.949997  108.739998  106.900002  108.680000  106.922302
# 2022-12-27  109.269997  110.470001  108.830002  110.190002  108.407875
# 2022-12-28  109.910004  110.000000  107.900002  108.379997  106.627151
# 2022-12-29  107.989998  109.720001  107.989998  109.199997  107.433884
# 2022-12-30  108.610001  110.500000  108.610001  110.300003  108.516098
#
#                 Volume Ticker
# Date
# 2012-12-03   364280000   AAPL
# 2012-12-04   557068400   AAPL
# ...

# %%
combined_data['Ticker'].unique()
# Out:
# array(['AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'AIG', 'AMD', 'AMGN', 'AMT',
#        'AMZN', 'AVGO', 'AXP', 'BA', 'BAC', 'BK', 'BKNG', 'BLK', 'BMY',
#        'C', 'CAT', 'CHTR', 'CL', 'CMCSA', 'COF', 'COP', 'COST', 'CRM',
#        'CSCO', 'CVS', 'CVX', 'DHR', 'DIS', 'DOW', 'DUK', 'EMR', 'EXC',
#        'F', 'FDX', 'GD', 'GE', 'GILD', 'GM', 'GOOG', 'GOOGL', 'GS', 'HD',
#        'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KHC', 'KO', 'LIN', 'LLY',
#        'LMT', 'LOW', 'MA', 'MCD', 'MDLZ', 'MDT', 'MET', 'META', 'MMM',
#        'MO', 'MRK', 'MS', 'MSFT', 'NEE', 'NFLX', 'NKE', 'NVDA', 'ORCL',
#        'PEP', 'PFE', 'PG', 'PM', 'PYPL', 'QCOM', 'RTX', 'SBUX', 'SCHW',
#        'SO', 'SPG', 'T', 'TGT', 'TMO', 'TMUS', 'TSLA', 'TXN', 'UNH',
#        'UNP', 'UPS', 'USB', 'V', 'VZ', 'WBA', 'WFC', 'WMT', 'XOM'],
#       dtype=object)
